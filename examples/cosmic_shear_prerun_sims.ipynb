# %% [markdown]
# ## Import stuff

# %%
import numpy as np
import matplotlib.pyplot as plt
import pydelfi.priors as priors
import pydelfi.ndes as ndes
import pydelfi.delfi as delfi
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
# %matplotlib inline
# Out:
# WARNING:tensorflow:From C:\Users\Davide\Anaconda3\lib\site-packages\pydelfi-0.1-py3.6.egg\pydelfi\train.py:9: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.

# %% [markdown]
# ## Set up the prior

# %%
lower = np.array([0, 0.4, 0, 0.4, 0.7])
upper = np.array([1, 1.2, 0.1, 1.0, 1.3])
prior = priors.Uniform(lower, upper)

# %% [markdown]
# ## Load in the compressed data vector, sims, Fisher matrix, fiducial params
# `compressed_data` is an array of length `n_summaries`<br>
# `sim_params` is an array with shape `(n_simulations, n_parameters)`<br>
# `sim_compressed_data` is an array with shape `(n_simulations, n_summaries)`

# %%
compressed_data = np.genfromtxt('simulators/cosmic_shear/pre_ran_sims/compressed_data.dat')

sim_params = np.genfromtxt('simulators/cosmic_shear/pre_ran_sims/simulations_parameters.dat')

sim_compressed_data = np.genfromtxt('simulators/cosmic_shear/pre_ran_sims/simulations_compressed_data.dat')

Finv = np.genfromtxt('simulators/cosmic_shear/pre_ran_sims/Finv.dat')

theta_fiducial = np.array([0.3, 0.8, 0.05, 0.70, 0.96])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(sim_params[:, 1], 20, histtype='step');

# %% [markdown]
# ## Create ensemble of NDEs

# %%
NDEs = [ndes.ConditionalMaskedAutoregressiveFlow(n_parameters=5, n_data=5, n_hiddens=[50,50], n_mades=5, act_fun=tf.tanh, index=0),
        ndes.MixtureDensityNetwork(n_parameters=5, n_data=5, n_components=1, n_hidden=[30,30], activations=[tf.tanh, tf.tanh], index=1)]#,
        #ndes.MixtureDensityNetwork(n_parameters=5, n_data=5, n_components=2, n_hidden=[30,30], activations=[tf.tanh, tf.tanh], index=2),
        #ndes.MixtureDensityNetwork(n_parameters=5, n_data=5, n_components=3, n_hidden=[30,30], activations=[tf.tanh, tf.tanh], index=3),
        #ndes.MixtureDensityNetwork(n_parameters=5, n_data=5, n_components=4, n_hidden=[30,30], activations=[tf.tanh, tf.tanh], index=4),
        #ndes.MixtureDensityNetwork(n_parameters=5, n_data=5, n_components=5, n_hidden=[30,30], activations=[tf.tanh, tf.tanh], index=5)]

# %% [markdown]
# ## Create DELFI object

# %%
DelfiEnsemble = delfi.Delfi(compressed_data, prior, NDEs, 
                            Finv = Finv, 
                            theta_fiducial = theta_fiducial, 
                            param_limits = [lower, upper],
                            param_names = ['\Omega_m', 'S_8', '\Omega_b', 'h', 'n_s'], 
                            results_dir = "simulators/cosmic_shear/results_prerun/",
                            input_normalization="fisher")

# %% [markdown]
# ## Load simulations into DELFI object

# %%
DelfiEnsemble.load_simulations(sim_compressed_data, sim_params)

# %% [markdown]
# ## Fisher pre-training to initialize networks

# %%
DelfiEnsemble.fisher_pretraining(n_batch=5000, batch_size=100)
# Out:
# HBox(children=(IntProgress(value=0, description='Training', max=1000, style=ProgressStyle(description_width='i…
# HBox(children=(IntProgress(value=0, description='Training', max=1000, style=ProgressStyle(description_width='i…
# Sampling approximate posterior...
# Done.
# Removed no burn in
# WARNING:root:auto bandwidth for \Omega_m very small or failed (h=0.0007196955936205117,N_eff=100000.0). Using fallback (h=0.012035794173342476)
# WARNING:root:auto bandwidth for \Omega_b very small or failed (h=0.0008429032180001177,N_eff=100000.0). Using fallback (h=0.016661964265614646)
# WARNING:root:auto bandwidth for n_s very small or failed (h=0.0007513524958689861,N_eff=100000.0). Using fallback (h=0.01374275240566613)
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# C:\Users\Davide\Anaconda3\lib\site-packages\pydelfi-0.1-py3.6.egg\pydelfi\delfi.py:626: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # Train the networks

# %%
DelfiEnsemble.train_ndes()
# Out:
# HBox(children=(IntProgress(value=0, description='Training', max=500, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Training', max=500, style=ProgressStyle(description_width='in…

# %% [markdown]
# # Sample the learned posterior

# %%
posterior_samples = DelfiEnsemble.emcee_sample()

# %% [markdown]
# # Alright let's plot it!
# Feed it a list of `(n_samples, n_parameters)` arrays for making a triangle plot; in this case let's just plot the posterior samples.

# %%
DelfiEnsemble.triangle_plot(samples=[posterior_samples])
# Out:
# Removed no burn in
# WARNING:root:auto bandwidth for \Omega_b very small or failed (h=0.000645054956544954,N_eff=100000.0). Using fallback (h=0.018164959937195482)
# WARNING:root:auto bandwidth for h very small or failed (h=0.0006766128789590877,N_eff=100000.0). Using fallback (h=0.014076325392912354)
# WARNING:root:auto bandwidth for n_s very small or failed (h=0.000643775469736984,N_eff=100000.0). Using fallback (h=0.01191737795542236)
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# C:\Users\Davide\Anaconda3\lib\site-packages\pydelfi-0.1-py3.6.egg\pydelfi\delfi.py:626: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
